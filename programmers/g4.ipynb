# %% [markdown]
# # 5. 완전탐색

# %% [markdown]
# ## 5.3. 카펫

# %%
def solution(brown, yellow):
    answer = []
    return answer

# %%
brown = 10
yellow = 2

erea = brown+yellow
answer = []
for y in range(1, erea+1): ##y(높이)가 1부터 12(넓이)까지
   if (erea/y)%1 == 0: ## x*y는 erea이니까 x*y꼴로 떨어지는지
      x = erea/y
      if x>= y: #가로가 더 넓다면
        if 2*x + 2*y == brown +4: # brown 개수
        #if x*y - 2*x - 2*y == yellow+4: 이건 왜 안돼
          answer.append(int(x))
          answer.append(int(y))
answer
# Out:
# []

# %% [markdown]
# # 6. 탐욕법

# %% [markdown]
# ## 6.1. 체육복

# %% [markdown]
# 구글링해씀 set은 -를 써도된당 ..

# %%
def solution(n, lost, reserve):
    answer = 0
    return answer

# %%
n = 5
lost = [2, 4]#[2, 4]	
reserve =[1,3,5] # [1, 3, 6]

lost_n = list(set(lost) - set(reserve))
reserve_n = list(set(reserve) - set(lost)) 
print(lost_n)

answer = n-len(lost_n)

for i in lost_n:
  if i-1 in reserve_n:
      answer += 1
      reserve_n.remove(i-1)
  elif i+1 in reserve_n:
      answer += 1
      reserve_n.remove(i+1)

answer
# Out:
# [2, 4]
# 5

# %% [markdown]
# 다른사람 풀이

# %%
def solution(n, lost, reserve):
    _reserve = [r for r in reserve if r not in lost]
    _lost = [l for l in lost if l not in reserve]
    for r in _reserve:
        f = r - 1
        b = r + 1
        if f in _lost:
            _lost.remove(f)
        elif b in _lost:
            _lost.remove(b)
    return n - len(_lost)

# %% [markdown]
# ## 6.2. 조이스틱

# %%
def solution(name):
    answer = 0
    return answer

# %%
name = "JEROEN"
temp = [ord(i) for i in name]
ans = [ord("A") for _ in name]
count = 0
l = []
#알파벳 변경 위 아래
for i in range(len(temp)):
  if temp[i]-ans[i] <=13:
    l.append(temp[i]-ans[i]) ## temp[i]-65 한거임
  elif temp[i]-ans[i] > 13:
    l.append(91-temp[i])
count = sum(l)
count = count + len(temp) - 1
count
#커서 변경
# Out:
# 56

# %%
print(temp)
print(ans)
#temp[i] > int(len(temp)/2):
# Out:
# [74, 69, 82, 79, 69, 78]
# [65, 65, 65, 65, 65, 65]

# %%
name = "ABAAAA"
temp = [ord(i) for i in name]
ans = [ord("A") for _ in name]
count = 0
l = []
#알파벳 변경 위 아래
for i in range(len(temp)):
  if temp[i]-ans[i] <=13:
    l.append(temp[i]-ans[i]) ## temp[i]-65 한거임
  elif temp[i]-ans[i] > 13:
    l.append(91-temp[i])

count = sum(l)
count1 = count + len(temp) - 1
count2 = count + len(temp) - 1

while len(temp) != 0:
#순방향일때
  if temp[-1] == 65: #A가 들어있으면 
    print('temp1', temp)
    count1 = count1 - 1
    temp.pop(-1)
    if temp[-1] != 65:
      break
  else:
    break

temp = [ord(i) for i in name]
while len(temp) != 0:
#역방향일때
  if temp[1] == 65: #A가 들어있으면 
    print('temp2', temp)
    count2 = count2 - 1
    temp.pop(1)
    if temp[1] != 65:
      break
  else:
    break

min(count1, count2)
# Out:
# 10

# %%
temp[-1]
# Out:
# 78

# %% [markdown]
# ## 6.3. 큰 수 만들기

# %% [markdown]
# 어떤 숫자에서 k개의 수를 제거했을 때 얻을 수 있는 가장 큰 숫자를 구하려 합니다.
#
#
# 예를 들어, 숫자 1924에서 수 두 개를 제거하면 [19, 12, 14, 92, 94, 24] 를 만들 수 있습니다. 이 중 가장 큰 숫자는 94 입니다.
#
#
# 문자열 형식으로 숫자 number와 제거할 수의 개수 k가 solution 함수의 매개변수로 주어집니다. number에서 k 개의 수를 제거했을 때 만들 수 있는 수 중 가장 큰 숫자를 문자열 형태로 return 하도록 solution 함수를 완성하세요.

# %% [markdown]
# * number는 1자리 이상, 1,000,000자리 이하인 숫자입니다.
# * k는 1 이상 number의 자릿수 미만인 자연수입니다.

# %% [markdown]
# * 입출력 예
#
# number	k	return
#
# "1924"	2	"94"
#
# "1231234"	3	"3234"
#
# "4177252841"	4	"775841"

# %%
def solution(number, k):
    answer = ''
    return answer

# %%
import itertools

number = "1231234"
k = 3
npr = itertools.combinations(number, len(number)-k)
npr = list(npr)
max([ int("".join(npr[i])) for i in range(len(npr))])
# Out:
# [('1', '2', '3', '1'),
#  ('1', '2', '3', '2'),
#  ('1', '2', '3', '3'),
#  ('1', '2', '3', '4'),
#  ('1', '2', '1', '2'),
#  ('1', '2', '1', '3'),
#  ('1', '2', '1', '4'),
#  ('1', '2', '2', '3'),
#  ('1', '2', '2', '4'),
#  ('1', '2', '3', '4'),
#  ('1', '3', '1', '2'),
#  ('1', '3', '1', '3'),
#  ('1', '3', '1', '4'),
#  ('1', '3', '2', '3'),
#  ('1', '3', '2', '4'),
#  ('1', '3', '3', '4'),
#  ('1', '1', '2', '3'),
#  ('1', '1', '2', '4'),
#  ('1', '1', '3', '4'),
#  ('1', '2', '3', '4'),
#  ('2', '3', '1', '2'),
#  ('2', '3', '1', '3'),
#  ('2', '3', '1', '4'),
#  ('2', '3', '2', '3'),
#  ('2', '3', '2', '4'),
#  ('2', '3', '3', '4'),
#  ('2', '1', '2', '3'),
#  ('2', '1', '2', '4'),
#  ('2', '1', '3', '4'),
#  ('2', '2', '3', '4'),
#  ('3', '1', '2', '3'),
#  ('3', '1', '2', '4'),
#  ('3', '1', '3', '4'),
#  ('3', '2', '3', '4'),
#  ('1', '2', '3', '4')]

# %%
max([ int("".join(npr[i])) for i in range(len(npr))])
# Out:
# 3234

# %%
answer = list(map(lambda i : ''.join(i), npr))
answer = max(answer)
answer = str(rmax)answer

# %% [markdown]
# 풀이2

# %% [markdown]
# ![스크린샷 2021-11-12 오전 11.24.22.png](data:image/png;base64,...)

# %%
number = "1231234"
k = 3

stack = [number[0]]
#print(stack)
for num in number[1:]:
    # 들어오는 값이 stack 값보다 크면, 기존의 값을 제거하고 새로운 값으로 바꿈 
    # 참고 : len(stack) > 0 == stack
  print('stack :', stack)
  while len(stack) > 0 and stack[-1] < num and k > 0:
      print('s-1,', stack[-1])
      print('n', num)
      # 값을 한개 빼서 k는 1이 제거 
      k -= 1
      # 내부의 값을 제거 
      stack.pop()
      # 새로운 값을 삽입 
  stack.append(num)
    # 만일 충분히 제거하지 못했으면 남은 부분은 단순하게 삭제
    # 이렇게 해도 되는 이유는 이미 큰 수부터 앞에서 채워넣었기 때문 
if k != 0:
  stack = stack[:-k]
print(''.join(stack))
# Out:
# stack : ['1']
# s-1, 1
# n 2
# stack : ['2']
# s-1, 2
# n 3
# stack : ['3']
# stack : ['3', '1']
# s-1, 1
# n 2
# stack : ['3', '2']
# stack : ['3', '2', '3']
# 3234

# %% [markdown]
# ## 6.4. 구명보트

# %% [markdown]
# 무인도에 갇힌 사람들을 구명보트를 이용하여 구출하려고 합니다. 구명보트는 작아서 한 번에 최대 2명씩 밖에 탈 수 없고, 무게 제한도 있습니다.
#
# 예를 들어, 사람들의 몸무게가 [70kg, 50kg, 80kg, 50kg]이고 구명보트의 무게 제한이 100kg이라면 2번째 사람과 4번째 사람은 같이 탈 수 있지만 1번째 사람과 3번째 사람의 무게의 합은 150kg이므로 구명보트의 무게 제한을 초과하여 같이 탈 수 없습니다.
#
# 구명보트를 최대한 적게 사용하여 모든 사람을 구출하려고 합니다.
#
# 사람들의 몸무게를 담은 배열 people과 구명보트의 무게 제한 limit가 매개변수로 주어질 때, 모든 사람을 구출하기 위해 필요한 구명보트 개수의 최솟값을 return 하도록 solution 함수를 작성해주세요.

# %% [markdown]
# 제한사항
#
# * 무인도에 갇힌 사람은 1명 이상 50,000명 이하입니다.
#
# * 각 사람의 몸무게는 40kg 이상 240kg 이하입니다.
#
# * 구명보트의 무게 제한은 40kg 이상 240kg 이하입니다.
#
# * 구명보트의 무게 제한은 항상 사람들의 몸무게 중 최댓값보다 크게 주어지므로 사람들을 구출할 수 없는 경우는 없습니다.

# %% [markdown]
# * 입출력 예
#
# people	limit	return
#
# [70, 50, 80, 50]	100	3
#
# [70, 80, 50]	100	3

# %%
def solution(people, limit):
    answer = 0
    return answer

# %%
people = [70, 80, 50]
limit = 100

temp = []
count = 0

num = len(people)
try:
  while num != 0:
    num -= 1
    for i in people[1:]:
      print(people)
      if people[0] + i <= limit:
        people.remove(people[0])
        people.remove(i)
        count += 1
        print('성공')

    people.remove(people[0])
    count += 1

except IndexError:
  pass


count
# Out:
# [70, 80, 50]
# [70, 80, 50]
# [80, 50]
# 3

# %%
people = [70, 50, 80, 50]
people.remove(70)
people
# Out:
# [50, 80, 50]

# %% [markdown]
# 다시 풀어보자 ..

# %%
people = [70, 80, 50,30,20,100]
limit = 100

temp = []
count = 0

people.sort()
print(people)

min = 0c
max = len(people)-1

while min <= max:
  count += 1
  if people[min] + people[max] <= limit:
    min +=1
  max -= 1
# Out:
# [20, 30, 50, 70, 80, 100]

# %%
def solution(people, limit):
    answer = 0
    
    people.sort()
    
    start, end = 0, len(people) - 1
    
    while start <= end:
        answer += 1
        if people[start] + people[end] <= limit:
            start += 1
        end -= 1
    
    return answer

# %%
k = [1,2,3]
while k:
  print(k.pop())
# Out:
# 3
# 2
# 1

# %% [markdown]
# 다른사람 풀이

# %%
from collections import deque

def solution(people, limit):
    result = 0
    deque_people = deque(sorted(people))

    while deque_people:
        left = deque_people.popleft()
        if not deque_people:
            return result + 1
        right = deque_people.pop()
        if left + right > limit:
            deque_people.appendleft(left)
        result += 1
    return result

# %% [markdown]
# # 동적 계획법

# %% [markdown]
# ## N으로 표현

# %% [markdown]
# 아래와 같이 5와 사칙연산만으로 12를 표현할 수 있습니다.
#
# 12 = 5 + 5 + (5 / 5) + (5 / 5)
# 12 = 55 / 5 + 5 / 5
# 12 = (55 + 5) / 5
#
# 5를 사용한 횟수는 각각 6,5,4 입니다. 그리고 이중 가장 작은 경우는 4입니다.
# 이처럼 숫자 N과 number가 주어질 때, N과 사칙연산만 사용해서 표현 할 수 있는 방법 중 N 사용횟수의 최솟값을 return 하도록 solution 함수를 작성하세요.

# %% [markdown]
# * 제한사항
#
# N은 1 이상 9 이하입니다.
#
# number는 1 이상 32,000 이하입니다.
#
# 수식에는 괄호와 사칙연산만 가능하며 나누기 연산에서 나머지는 무시합니다.
#
# 최솟값이 8보다 크면 -1을 return 합니다.

# %% [markdown]
# * 입출력 예
#
# N	number	return
#
# 5	12	4
#
# 2	11	3

# %%
|
